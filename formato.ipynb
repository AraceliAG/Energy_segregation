# %%
import os
import pandas as pd

def concat_txt_to_csv(directory, output_csv):
    # Lista para almacenar los datos de todos los archivos
    data_frames = []
    
    # Iterar sobre todos los archivos en la carpeta
    for file in os.listdir(directory):
        if file.endswith(".txt"):
            file_path = os.path.join(directory, file)
            print(f"Leyendo archivo: {file_path}")
            
            # Leer cada archivo .txt en un DataFrame
            df = pd.read_csv(file_path, header=None)  # Ajusta el delimitador si es necesario
            data_frames.append(df)
    
    # Concatenar todos los DataFrames en uno solo
    combined_df = pd.concat(data_frames, ignore_index=True)
    
    # Guardar el DataFrame concatenado en un archivo CSV
    combined_df.to_csv(output_csv, index=False, header=False)
    print(f"Archivos concatenados guardados en: {output_csv}")

# Especifica el directorio de los archivos .txt y el nombre del archivo de salida .csv
directory = 'Corriente_linea1'
output_csv = 'datos_generales.csv'

concat_txt_to_csv(directory, output_csv)
# Out:
# Leyendo archivo: Corriente_linea1\2024-09-25 15.txt
# Leyendo archivo: Corriente_linea1\2024-09-25 16.txt
# Archivos concatenados guardados en: datos_generales.csv

# %%
#COncatenar


import pandas as pd
import os

# Especifica la ruta de la carpeta que contiene los archivos .txt
carpeta = 'Corriente_linea1'  # Cambia esto a la ruta de tu carpeta
archivos_txt = [f for f in os.listdir(carpeta) if f.endswith('.txt')]
df = pd.read_csv(ruta_archivo, delimiter='\t', header=None)  # Cambia delimiter si es necesario

# Lista para almacenar los DataFrames
dataframes = []

# Leer cada archivo .txt y agregarlo a la lista
for archivo in archivos_txt:
    ruta_archivo = os.path.join(carpeta, archivo)
    dataframes.append(df)

# Concatenar todos los DataFrames en uno solo
resultado = pd.concat(dataframes, ignore_index=True)

# Guardar el resultado en un archivo .csv
resultado.to_csv('datos_generalesD.csv', index=False)

print("Archivos concatenados y guardados en 'archivo_concatenado.csv'")
# Out:
# Archivos concatenados y guardados en 'archivo_concatenado.csv'

# %%
data = pd.read_csv('datos_generales3.csv')

print(data.head())
# Out:
#    2024-09-25 13-00-0.3   0.3166365623474121
# 0  2024-09-25 13-00-1.1             0.319742
# 1  2024-09-25 13-00-2.0             0.319742
# 2  2024-09-25 13-00-2.8             0.320999
# 3  2024-09-25 13-00-3.6             0.321537
# 4  2024-09-25 13-00-4.4             0.322182

# %%
import pandas as pd

# Cargar los datos desde un archivo CSV (ajusta la ruta si es necesario)
data = pd.read_csv('datos_generales3.csv')


# Eliminar los microsegundos (elimina la parte después del último punto)
data['fecha'] = data['fecha'].str.replace(r'\.\d+$', '', regex=True)

# Reemplazar el espacio por un guion bajo
data['fecha'] = data['fecha'].str.replace(' ', '_')

# # Convertir la cadena a datetime
# data['fecha'] = pd.to_datetime(data['fecha'], format='%Y-%m-%d_%H-%M-%S')

# Guardar el resultado en un nuevo archivo CSV
data.to_csv('datos_generales4.csv', index=False)

# %% [markdown]
# VER COMPORTAMIENTO

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde un archivo CSV (ajusta la ruta si es necesario)
data = pd.read_csv('datos_generales4.csv')

# Graficar
plt.figure(figsize=(12, 6))
plt.plot(data['fecha'], data['Corriente_linea1'], marker='o', linestyle='-', color='b')
plt.title('Corriente del Refrigerador a lo Largo del Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Corriente (A)')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %%
print(min(data['fecha']))
print(max(data['fecha']))
# Out:
# 2024-09-25_13-00-0
# 2024-09-25_13-48-9
